# %% [markdown]
# ## Mécanique du vol, 2023-2024
# #### Université Paul Sabatier, ENSEEIHT
#
# Auteur: Christophe.Airiau@imft.fr
#
# <table style="width: 100%">
#     <colgroup>
#        <col span="1" style="width: 40%;">
#        <col span="1" style="width: 20%;">
#        <col span="1" style="width: 45%;">
#     </colgroup>
#     <tbody>
#         <tr>
#             <td style="background-color: #ffffff"><img src="Images/fsi.png" width="200"></td>
#             <td style="background-color: #ffffff"> </td>
#             <td style="background-color: #ffffff"><img src="Images/N7.png" width="200"></td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# # **<span style="color:orange">Polaire, finesse et puissance optimales</span>**
#
#
#
# # Introduction
#
#
#
# # **<span style="color:red">Objectifs</span>**
#
# 1. Déterminer les caractéristiques avions et aérodynamiques pour une configuration en finesse maximale
# 2. Déterminer les caractéristiques avions et aérodynamiques pour une configuration de puissance requise minimale
# 3. Utiliser un module Python pour résoudre un problème d'ingénierie
#
# Le TP est complexe, il a fallu plusieurs jours de travail pour arriver au bout, à cause de la complexité de certaines relations.
#
# Naturellement, ensuite le travail demandé est beaucoup plus simple.
#
# Il y a plusieurs parties, qu'il faut mener dans l'ordre si l'on veut comprendre quelque chose.
#
# **Attention, seul ce fichier sera à rendre au titre de compte-rendu de TP**
#
# Ainsi tout le travail doit être écrit dans ce fichier.
#
#
# Dans la suite les quantités d'intérêt ont des indices, qui correspondent au cas suivant:
#
# |                  | finesse maximale  | puissance requise minimale  |
# |:----------------:|:-----------------:|:----------------------------|
# | polaire centrée  |     **1 (ref)**   |            2                |
# |polaire décentrée |         3         |            4                |

# %% [markdown]
#  <hr style="border:2px solid orange " width="99%">
#
# # **<span style="color:red">A - Polaire centrée</span>**
#
#  <hr style="border:2px solid orange " width="99%">
#
# ## Procédure
#
# * Il faut ouvrir et lire dans son ensemble le fichier **polaire_classique.ipynb**
#
# * Certaines parties qui sont les détails des calculs utilisent le module `sympy`.
# * Si ce module ne fonctionne pas sur votre machine, se contenter de lire les résulats en *Latex*
#   et répondre aux questions.
#
# ## Etape 1: lecture et compréhension
#
# On considère une polaire centrée, comme celle vu en cours et TD.
#
# On considère deux cas:
# 1. le cas de la finesse maximale, et on calcule les coefficients aérodynamiques, la vitesse optimale et la puissance requise.
#     C'est le cas intéressant pour les avions à réactions
# 2. le cas de la puissance minimale et on calcule les coefficients aérodynamiques, la vitesse optimale et la puissance requise.
#     C'est le cas intéressant pour les avions à moteurs à pistons
#
# * Comme dit précédemment le fichier contient à la fois les calculs et la mise en forme des résultats en *Latex*.
#
# * Une application numérique permet de tester l'implémentation et permettra la validation dans la partie 3 du TP.
#
# * On peut lire rapidement si on a déjà bien compris le TD sur la traînée, quitte à y revenir plus tard.
#
# REPONDRE AUX QUESTIONS DANS LES ENDROITS OU S'EST ECRIT **réponse**

# %% [markdown]
# ## Etape 2: Analyse, codage
#
# Le codage est en Python classique avec `numpy`, ne pas utiliser `sympy`
#
# ###  **<span style="color:magenta"> Question 1: puissance optimale </span>**
#
# 1.  Comment évolue la puissance optimale en fonction du poids, quelque soit les cas considérés ? Donner la loi de puissance mathématique ?
#
# **réponse**
#
#
# 2. Comment évolue la puissance optimale en fonction de l'altitude ?
#
# **réponse**

# %% [markdown]
# ###  **<span style="color:magenta"> Question 2: vitesse optimale </span>**
#
# 1.  Comment évoluent les vitesses optimales en fonction de la masse ? Donner la loi de puissance mathématique.
#
# **réponse**
#
#
# 2. Comment évoluent les vitesses optimales en fonction de l'altitude ? Donner la loi de puissance mathématique.
#
# **réponse**
#
# 2. Comment évoluent les vitesses optimales en fonction de l'allongement ?
#
# Pour vérifier cela, tracer la vitesse $V_1$ pour un allongement  $4\leqslant \lambda \leqslant 25$.
# Pour les autres valeurs numériques, on prendra celles dans le fichier **polaire_classique.ipynb**.
#
# Ecrire le code et faire le graphique ci-dessous:

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

plt.xlabel(r"\lambda")
plt.ylabel(r"$V_1$ [km/h]")
# Out:
# Text(0, 0.5, '$V_1$ [km/h]')

# %% [markdown]
# ###  **<span style="color:magenta"> Question 3: conception inverse </span>**
#
# On donne :
#     $f_{\max} = 20$, $C_{L_1} = 0.3$, $V_1=330$ km/h, $Pr_1 = 280$ kW, $rho=1$ kg/m$^3$, $e=0.85$
#
#
# Trouver une procédure et écrire un petit code qui permet de calculer:
#
# $$C_{D_1}, W/S, W, m, S, C_{D_0}, k; \lambda$$
#
# Est-ce que les valeurs trouvées vous semblent réalistes ?

# %%
# code
f_max, CL_1, rho, e = 20, 0.3, 1, 0.85
V_1_kmh = 330
Pr_1_kw = 280
G = 9.81

# Ecrire ici

# Ne pas toucher aux sorties, sauf en les décommentant au fur et à mesure
# utiliser les noms des variables indiquées
# l'ordre d'affichage n'indique pas nécessairement l'ordre de la résolution

print("C_D1      : %.4f" % CD_1)
print("W/S       : %.4f" % W_S)
print("S         : %.4f m^2" % S)
print("m         : %.2f kg" % m)
print("k         : %.4f " % k)
print("C_D0      : %.4f " % C_D0)
print("lambda    : %.2f " % lambda_)  # attention bien suivre la notation lambda_
print("V_2       : %.2 km/f " % V_3*3.6)
print("Pr_2      : %.2f kW " % (Pr3/1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 13
#       5 G = 9.81
#       7 # Ecrire ici
#       8
#       9 # Ne pas toucher aux sorties, sauf en les décommentant au fur et à mesure
#      10 # utiliser les noms des variables indiquées
#      11 # l'ordre d'affichage n'indique pas nécessairement l'ordre de la résolution
# ---> 13 print("C_D1      : %.4f" % CD_1)
#      14 print("W/S       : %.4f" % W_S)
#      15 print("S         : %.4f m^2" % S)
#
# NameError: name 'CD_1' is not defined

# %% [markdown]
#  <hr style="border:2px solid orange " width="99%">
#
# # **<span style="color:red">B - Polaire décentrée</span>**
#
#  <hr style="border:2px solid orange " width="99%">
#
# ## Procédure
#
# * Il faut ouvrir et lire dans son semble le fichier **polaire_decentree.ipynb**
#
# * Certaines parties qui sont les détails des calculs utilisent le module `sympy`.
# * Si ce module ne fonctionne pas sur votre machine, se contenter de lire les résulats du *Latex* et répondre aux questions.
#
# ## Etape 1: lecture et compréhension
#
# On considère une polaire décentrée.
#
# On considère deux cas:
# 1. le cas de la finesse maximale, et on calcule les coefficients aérodynamiques, la vitesse optimale et la puissance requise.
#     C'est le cas intéressant pour les avions à réactions
# 2. le cas de la puissance minimale et on calcule les coefficients aérodynamiques, la vitesse optimale et la puissance requise.
#     C'est le cas intéressant pour les avions à moteurs à pistons
#
# * Comme dit précédemment le fichier contient à la fois les calculs et la mise en forme des résultats en *Latex*.
#
# * Une application numérique permet de tester l'implémentation et permettra la validation dans la partie 3 du TP.
#
# * On peut lire tout rapidement quitte à y revenir plus tard.
#
# **ATTENTION** Le notebook contient énormément de calculs, on peut / on doit s'attarder sur les formules encadrées en couleur. J'ai laissé les détails pour montrer la complexité du travail.
#
# * La démarche suit le notebook précédent, c'est juste plus compliqué à cause du décentrement.
#
# * De plus on s'attache à comparer au cas de référence (cas 1) en introduisant le paramètre $\epsilon$, c'est ce qui rend les choses complexes. Sans l'utilisation de $\epsilon$, le travail serait très (trop) simple.

# %% [markdown]
# ## Etape 2: Analyse, codage
#
# Le codage est en Python classique avec `numpy`, ne pas utiliser `sympy`.
#
# ###  **<span style="color:magenta"> Question 4:  graphique des corrections</span>**
#
# Coder un graphique sur lequel on voit les corrections
# $$
# \dfrac{C_{L_3}}{C_{L_{ref}}}, \dfrac{C_{D_3}}{C_{D_{ref}}}, \dfrac{Pr_3}{Pr_{ref}}, \dfrac{V_3}{V_{ref}}, \dfrac{f_3}{f_{ref}}
# $$
# pour $ 0 \leqslant \epsilon \leqslant 1$

# %%
import numpy as np
import matplotlib.pyplot as plt

eps = np.linspace(0, 1)


plt.figure()



plt.xlabel(r"\epsilon")
plt.grid()
plt.legend()
plt.title("Corrections")

# %% [markdown]
# Ecrire vos commentaires ou conclusions à partir du graphique
#
# *
#
# *
#
# *
#
# *
#
# *

# %% [markdown]
# ###  **<span style="color:magenta"> Question 5:  graphique des corrections de puissance </span>**
#
# On s'intéresse à la comparaison des deux puissances $Pr_3$ et $Pr_4$.
#
# Comment par exemple évoluent-elles en fonction du paramètres $epsilon$ qui définit le décentrement horizontal de la polaire ?
#
# Pour cela il faut faire deux graphes:
#
# 1. le premier contient deux courbes $Pr_4/ Pr_1$ et $Pr_3/Pr_1$ en fonction de $\epsilon$
# 2. le second ne contient qu'une courbe $Pr_4/Pr_3$ en fonction de $\epsilon$

# %%
# codage des deux plots ici

# %% [markdown]
# ###  **<span style="color:magenta"> Question 6:  graphique des finesses  </span>**
#
# On s'intéresse à la comparaison des deux finesses $f_3$ et $f_4$.
#
# Comment par exemple évoluent-elles en fonction du paramètres $epsilon$ qui définit le décentrement horizontal de la polaire ?
#
# Pour cela il faut faire deux graphes:
#
# 1. le premier contient deux courbes $f_4/ f_1$ et $f_3/f_1$ en fonction de $\epsilon$
# 2. le second ne contient qu'une courbe $f_4/f_3$ en fonction de $\epsilon$

# %% [markdown]
# **Remarques, conclusions sur le décentrement**

# %% [markdown]
# ###  **<span style="color:magenta"> Question 7: vitesses optimales  </span>**
#
# Analyser les variations des vitesses  $V_3$ et $V_4$ en fonction de $\epsilon$ (méthode de votre choix)
#
# **réponse:**

# %% [markdown]
#  <hr style="border:2px solid orange " width="99%">
#
# # **<span style="color:red">C- Conception inverse</span>**
#
#  <hr style="border:2px solid orange " width="99%">
#
# Un module a été écrit qui permet de faire la conception inverse à partir de la polaire décentrée.
#
# Cela ne sera pas effectué en TP.

# %% [markdown]
#  <hr style="border:2px solid orange " width="99%">
#
# # **<span style="color:red">D- Polaire générique</span>**
#
#  <hr style="border:2px solid orange " width="99%">
#
# Un module a été écrit qui permet de concevoir sa propre polaire manuellement, et donc qui n'obéit pas à une loi
# mathématique simple.
#
# Ensuite le module permet de déterminer les caractérisques de vol de l'avion en fonction de la polaire.
#
# Là encore cela ne sera pas abordé en TP.

# %% [markdown]
# <hr style="border:2px solid orange " width="99%">
#
# # **<span style="color:red">E- Conclusion, avis sur le TP</span>**
#
#  <hr style="border:2px solid orange " width="99%">
#
# Ecrire une conclusion sur le TP et l'intérêt,  donner votre avis, vos impressions, ce que vous avez appris, vos difficultés, etc ...

# %% [markdown]
# Texte ici:
